# %%
import requests

from bs4 import BeautifulSoup
 
    
def count_words(url, the_word):
    r = requests.get(url, allow_redirects=False)
    soup = BeautifulSoup(r.content, 'lxml')
    words = soup.find(text=lambda text: text and the_word in text)
    print(words)
    return len(words)
 
def main():
    url = input("enter the link")
    word = 'HIV'
    count = count_words(url, word)
    print('\nUrl: {}\ncontains {} occurrences of HIV related word: {}'.format(url, count, word))
    
if __name__ == '__main__':
    main()
# Out:
# enter the linkhttps://www.medicalnewstoday.com/articles/17131.php
# HIV and AIDS: Overview, causes, symptoms, and treatments
#
# Url: https://www.medicalnewstoday.com/articles/17131.php
# contains 56 occurrences of HIV related word: HIV
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c849c4711a07> in <module>
#      22
#      23
# ---> 24 plot.bar(count, height, width=0.8)
#
# NameError: name 'count' is not defined

# %%
times=('https://timesofindia.indiatimes.com/2010/1/1/archivelist/year-2010,month-1,starttime-40179.cms')
a=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 1 :",a)

times=('https://timesofindia.indiatimes.com/2010/1/2/archivelist/year-2010,month-1,starttime-40180.cms')
b=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 2   :",b)

times=('https://timesofindia.indiatimes.com/2010/1/3/archivelist/year-2010,month-1,starttime-40181.cms')
c=requests.get(times).text.count('HIV')
print ("no ofHIV words in news in a 1st month day 3  :",c)

times=('https://timesofindia.indiatimes.com/2010/1/4/archivelist/year-2010,month-1,starttime-40182.cms')
d=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 4 :",d)

times=('https://timesofindia.indiatimes.com/2010/1/5/archivelist/year-2010,month-1,starttime-40183.cms')
e=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 5  :",e)

times=('https://timesofindia.indiatimes.com/2010/1/5/archivelist/year-2010,month-1,starttime-40184.cms')
r=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 6  :",r)

times=('https://timesofindia.indiatimes.com/2010/1/6/archivelist/year-2010,month-1,starttime-40185.cms')
y=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 7  :",y)

times=('https://timesofindia.indiatimes.com/2010/1/7/archivelist/year-2010,month-1,starttime-40186.cms')
w=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 8  :",w)

times=('https://timesofindia.indiatimes.com/2010/1/8/archivelist/year-2010,month-1,starttime-40187.cms')
j=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 9  :",j)

times=('https://timesofindia.indiatimes.com/2010/1/9/archivelist/year-2010,month-1,starttime-40188.cms')
u=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 10  :",u)

times=('https://timesofindia.indiatimes.com/2010/1/10/archivelist/year-2010,month-1,starttime-40189.cms')
o=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 11  :",o)

times=('https://timesofindia.indiatimes.com/2010/1/11/archivelist/year-2010,month-1,starttime-40190.cms')
p=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 11  :",p)

times=('https://timesofindia.indiatimes.com/2010/1/12/archivelist/year-2010,month-1,starttime-40191.cms')
s=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 12  :",s)

times=('https://timesofindia.indiatimes.com/2010/1/13/archivelist/year-2010,month-1,starttime-40192.cms')
t=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 13  :",t)


times=('https://timesofindia.indiatimes.com/2010/1/14/archivelist/year-2010,month-1,starttime-40193.cms')
n=requests.get(times).text.count('HIV')
print ("no ofHIV words in news in a 1st month day 14  :",n)


times=('https://timesofindia.indiatimes.com/2010/1/14/archivelist/year-2010,month-1,starttime-40194.cms')
l=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 14  :",l)


times=('https://timesofindia.indiatimes.com/2010/1/15/archivelist/year-2010,month-1,starttime-40195.cms')
c=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 15  :",c)


times=('https://timesofindia.indiatimes.com/2010/1/16/archivelist/year-2010,month-1,starttime-40196.cms')
f=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 16  :",f)


times=('https://timesofindia.indiatimes.com/2010/1/17/archivelist/year-2010,month-1,starttime-40197.cms')
z=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 17  :",z)


times=('https://timesofindia.indiatimes.com/2010/1/18/archivelist/year-2010,month-1,starttime-40198.cms')
op=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 18  :",op)


times=('https://timesofindia.indiatimes.com/2010/1/19/archivelist/year-2010,month-1,starttime-40199.cms')
za=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 19  :",za)


times=('https://timesofindia.indiatimes.com/2010/1/20/archivelist/year-2010,month-1,starttime-40200.cms')
yu=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 20  :",yu)


times=('https://timesofindia.indiatimes.com/2010/1/21/archivelist/year-2010,month-1,starttime-40201.cms')
oi=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 21  :",oi)


times=('https://timesofindia.indiatimes.com/2010/1/22/archivelist/year-2010,month-1,starttime-40202.cms')
yt=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 22  :",yt)


times=('https://timesofindia.indiatimes.com/2010/1/23/archivelist/year-2010,month-1,starttime-40203.cms')
it=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 23  :",it)


times=('https://timesofindia.indiatimes.com/2010/1/24/archivelist/year-2010,month-1,starttime-40204.cms')
ut=requests.get(times).text.count('HIV')
print ("no of HIV words in news in a 1st month day 24  :",ut)

from matplotlib import pyplot as plt
plt.plot([a,b,c,d,r,y,w,j,u,o,p,s,t,n,l,f,c,z,ut,it,yt,oi,yu,za,op])
mean=((a+b+c+d+r+y+w+j+u+o+p+s+t+n+l+f+c+z+ut+it+yt+oi+yu+za+op)/24)
print("percentage of HIV realted issues in newspaper in a month:",mean)
plt.title("Occurence of HIV news in a month of Jan2010")
plt.xlabel("hiv words in month")
plt.ylabel("Frequency of HIV news")
plt.show()
# Out:
# no of HIV words in news in a 1st month day 1 : 0
# no of HIV words in news in a 1st month day 2   : 0
# no ofHIV words in news in a 1st month day 3  : 0
# no of HIV words in news in a 1st month day 4 : 0
# no of HIV words in news in a 1st month day 5  : 0
# no of HIV words in news in a 1st month day 6  : 0
# no of HIV words in news in a 1st month day 7  : 0
# no of HIV words in news in a 1st month day 8  : 4
# no of HIV words in news in a 1st month day 9  : 0
# no of HIV words in news in a 1st month day 10  : 0
# no of HIV words in news in a 1st month day 11  : 2
# no of HIV words in news in a 1st month day 11  : 2
# no of HIV words in news in a 1st month day 12  : 0
# no of HIV words in news in a 1st month day 13  : 0
# no ofHIV words in news in a 1st month day 14  : 0
# no of HIV words in news in a 1st month day 14  : 0
# no of HIV words in news in a 1st month day 15  : 0
# no of HIV words in news in a 1st month day 16  : 0
# no of HIV words in news in a 1st month day 17  : 0
# ...
